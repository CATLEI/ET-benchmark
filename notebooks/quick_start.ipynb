# %% [markdown]
# # ET-dflow Benchmark Framework - Quick Start
#
# This notebook provides a quick introduction to using the ET-dflow Benchmark Framework.

# %%
# Import framework
import et_dflow as et
from et_dflow.application.cli import cli
from et_dflow.infrastructure.utils.config_wizard import SimpleMode

# %% [markdown]
# ## 1. Create Simple Configuration

# %%
# Create simple configuration
config = SimpleMode.create_simple_config(
    dataset_path="./data/my_dataset.hspy",
    algorithm="wbp",
    output_dir="./results"
)

print("Configuration created:")
print(config)
